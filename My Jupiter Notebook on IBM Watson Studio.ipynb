# %% [markdown]
# <h1>My Jupiter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <b>Pablo David Mena Medrano</b> <br />
# Gestor de proyectos

# %% [markdown]
# <i>Estoy interesado en la Data Science porque permite definir problemas, establecer las mejores herramientas analíticas aprovechando los datos del negocio.</i>

# %% [markdown]
# <h3>El siguiente código busca calcular una fórmula de ecuación lineal :  </h3>

# %%
def lineal(a, b, x):
    return a*x+b

lineal(1, 2022, 3)
# Out:
# 2025

# %% [markdown]
# Años de la pandemia
#
# <ul>
# <li>2020</li>
# <li>2021</li>
# <li>2022</li>
# <li>2023</li>
# <li>2024</li>
# <li>2025</li>
# </ul>
#
# Valores de X
# <ol>
#     <li>10</li>
#     <li>20</li>
#     <li>30</li>
# </ol>
#
# Vocales <br/>
# <ol>
# <li>A</li>
# <li>E</li>
# <li>I</li>
# <li>O</li>
# <li>U</li>
# </ol>
#
# Vocales <br/>
# <ul>
# <li>A</li>
# <li>E</li>
# <li>I</li>
# <li>O</li>
# <li>U</li>
# </ul>
#
#
# Página de la upc : https://www.upc.edu.pe/
