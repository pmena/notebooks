# %% [markdown]
# <h1>My Jupiter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <b>Paola Paredes</b> <br/>
# <h4>Asistente administrativo Poder Judicial</h4>

# %% [markdown]
# <i>Estoy interesada en DataScience porque permite resolver problemas de las empresa en base a datos o hechos concretos.</i>

# %% [markdown]
# <h3>Calculo la resta de 2 números:  </h3>

# %%
def restaAB(a, b):
    return a-b

restaAB(10, 6)
# Out:
# 4

# %% [markdown]
# Enlace para búsqueda : <a href ="http://www.google.com.pe">http://www.google.com.pe</a>
#
# <hr />
# <hr />
#
# <table>
# <tr>
#     <td>Carrera</td>
#     <td>Año de ingreso</td>
# </tr>
# <tr>
#     <td>Administración de empresas</td>
#     <td>2019</td>
# </tr>
# </table>
