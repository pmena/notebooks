# %%
# !pip install yfinance==0.1.67
#!pip install pandas==1.3.3

import yfinance as yf
# Out:
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.10-py3-none-any.whl size=8487 sha256=4670d313c169cc440ad7dd4d42acc2595de259036d6b5108e85884506efa918b
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/21/c9/66/b41c847de65c7985db52ec21d59996841598b8b0e93f2b9500
# Successfully built multitasking
# ...

# %%
#Carga de datos de TESLA

tesla = yf.Ticker("TSLA")

tesla_share_price_data.reset_index(inplace=True)
tesla_share_price_data.plot(x="Date", y="Open")

tesla_share_price_data = tesla.history(period="max")
tesla_share_price_data.head()
# Out:
#              Open   High    Low  Close    Volume  Dividends  Stock Splits
# Date
# 2010-06-29  3.800  5.000  3.508  4.778  93831500          0           0.0
# 2010-06-30  5.158  6.084  4.660  4.766  85935500          0           0.0
# 2010-07-01  5.000  5.184  4.054  4.392  41094000          0           0.0
# 2010-07-02  4.600  4.620  3.742  3.840  25699000          0           0.0
# 2010-07-06  4.000  4.000  3.166  3.222  34334500          0           0.0

# %%
#Webscraping de los datos de TESLA

tesla = yf.Ticker("TSLA")

tesla.dividends
tesla.dividends.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Web scrapping

# !mamba install bs4==4.10.0 -y
# !pip install lxml==4.6.4
# !mamba install html5lib==1.1 -y
# !pip install requests==2.26.0

from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page
# Out:
# /usr/bin/sh: mamba: command not found
# ...
#      |████████████████████████████████| 6.9 MB 12.0 MB/s eta 0:00:01
# ...
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.7.1
#     Uninstalling lxml-4.7.1:
#       Successfully uninstalled lxml-4.7.1
# ...
# /usr/bin/sh: mamba: command not found

# %%
#Webscraping de datos de YAHOO
url = "https://finance.yahoo.com/quote/TSLA/?guccounter=1&guce_referrer=aHR0cHM6Ly93d3cuZ29vZ2xlLmNvbS8&guce_referrer_sig=AQAAAGqO_dx4K6P3dsQWg6Waqaz3ErzfwDcr9MfK2Bcepb5yCrobvGIWK26AZsJy_G5Z8U5c5k-Fg9OnHIr-n48KLlofxzKOf7y18sjbiBcQXNXWq6VySe-k98l3PW9h2_J4FCHRFZY_QGnKFw-HrrqxnKRXlW6MC9uGFbhcGFKCQ1Fh"

data  = requests.get(url).text 
soup = BeautifulSoup(data,"html.parser")
table = soup.find('table')

for row in table.find_all('tr'): 
    cols = row.find_all('td') 
    label = cols[0].string
    price = cols[1].string
    print("{} --> {}".format(label, price))
# Out:
# Previous Close --> 922.00
# Open --> 935.00
# Bid --> 935.78 x 800
# Ask --> 936.17 x 800
# Day's Range --> 922.09 - 946.27
# 52 Week Range --> 539.49 - 1,243.49
# Volume --> 13,113,974
# Avg. Volume --> 26,753,659

# %%
#Carga de datos de Stock

tesla = yf.Ticker("TSLA")

tesla_share_price_data.reset_index(inplace=True)
tesla_share_price_data.plot(x="Date", y="Open")

tesla_share_price_data = tesla.history(period="max")
tesla_share_price_data.head()

# %%
def make_graph(strCode):
    print("Carga de datos ",strCode)
    gme_share_price_data = gme.history(period="max")
    gme_share_price_data.reset_index(inplace=True)
    gme_share_price_data.plot(x="Date", y="Open")

#Carga de datos de Gamespot
strCode = "GME"
gme = yf.Ticker(strCode)
make_graph(strCode)
# Out:
# Carga de datos  GME

# %%
def make_graph(data):
    import matplotlib.pyplot as plt
    

    
    #x=len(data["Date"])
    #y1=data["Open"]  
    #plt.bar(range(x),y1.values())
    #plt.show()

gme = yf.Ticker("GME")
#gme_share_price_data = gme.history(period="max")
#df = gme_share_price_data.head()

gme_share_price_data = gme.history(period="max")
gme_share_price_data.head()

#datos = df["Open"]
#datos
#datos.split("")
#make_graph(df)

#x= df["Date"]
#y= df["Open"]
#plt.plot
# Out:
#                 Open      High       Low     Close    Volume  Dividends  \
# Date
# 2002-02-13  6.480514  6.773400  6.413183  6.766666  19054000        0.0
# 2002-02-14  6.850829  6.864295  6.682504  6.733001   2755400        0.0
# 2002-02-15  6.733000  6.749832  6.632005  6.699335   2097400        0.0
# 2002-02-19  6.665670  6.665670  6.312187  6.430015   1852600        0.0
# 2002-02-20  6.463683  6.648840  6.413185  6.648840   1723200        0.0
#
#             Stock Splits
# Date
# 2002-02-13           0.0
# 2002-02-14           0.0
# 2002-02-15           0.0
# 2002-02-19           0.0
# 2002-02-20           0.0

# %%
def make_graph(strCode):
    print("Carga de datos ",strCode)
    gme_share_price_data = gme.history(period="max")
    gme_share_price_data.reset_index(inplace=True)
    gme_share_price_data.plot(x="Date", y="Open")

#Carga de datos de Gamespot
strCode = "TSLA"
gme = yf.Ticker(strCode)
make_graph(strCode)
# Out:
# Carga de datos  TSLA

# %%
strCode = "TSLA"
st = yf.Ticker(strCode)
st_share_price_data = st.history(period="max")
df=st_share_price_data.head()
df["Dividends"].tail()
# Out:
# Date
# 2010-06-29    0
# 2010-06-30    0
# 2010-07-01    0
# 2010-07-02    0
# 2010-07-06    0
# Name: Dividends, dtype: int64

# %%
strCode = "TSLA"
st = yf.Ticker(strCode)
st_share_price_data = st.history(period="max")
df=st_share_price_data.head()
df.head()
# Out:
#              Open   High    Low  Close    Volume  Dividends  Stock Splits
# Date
# 2010-06-29  3.800  5.000  3.508  4.778  93831500          0           0.0
# 2010-06-30  5.158  6.084  4.660  4.766  85935500          0           0.0
# 2010-07-01  5.000  5.184  4.054  4.392  41094000          0           0.0
# 2010-07-02  4.600  4.620  3.742  3.840  25699000          0           0.0
# 2010-07-06  4.000  4.000  3.166  3.222  34334500          0           0.0

# %%
strCode = "GME"
st = yf.Ticker(strCode)
st_share_price_data = st.history(period="max")
st_share_price_data.head()
# Out:
#                 Open      High       Low     Close    Volume  Dividends  \
# Date
# 2002-02-13  6.480515  6.773401  6.413185  6.766668  19054000        0.0
# 2002-02-14  6.850830  6.864296  6.682505  6.733003   2755400        0.0
# 2002-02-15  6.733002  6.749834  6.632007  6.699337   2097400        0.0
# 2002-02-19  6.665669  6.665669  6.312187  6.430015   1852600        0.0
# 2002-02-20  6.463680  6.648838  6.413182  6.648838   1723200        0.0
#
#             Stock Splits
# Date
# 2002-02-13           0.0
# 2002-02-14           0.0
# 2002-02-15           0.0
# 2002-02-19           0.0
# 2002-02-20           0.0

# %%
#Webscraping de datos de YAHOO de GME
url = "https://finance.yahoo.com/quote/GME/"

data  = requests.get(url).text 
soup = BeautifulSoup(data,"html.parser")
table = soup.find('table')

for row in table.find_all('tr'): 
    cols = row.find_all('td') 
    label = cols[0].string
    price = cols[1].string
    print("{} --> {}".format(label, price))
# Out:
# Previous Close --> 124.29
# Open --> 114.09
# Bid --> 0.00 x 1000
# Ask --> 0.00 x 800
# Day's Range --> 116.00 - 121.12
# 52 Week Range --> 38.50 - 348.50
# Volume --> 361,881
# Avg. Volume --> 3,050,809
